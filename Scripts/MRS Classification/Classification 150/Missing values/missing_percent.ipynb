# %%
import pandas as pd

# %%
# Load the Excel file
file_path = 'PHD MRI+CTA+MRS 150 complete.xlsx'  # Replace with your Excel file path
data = pd.read_excel(file_path)

# %%
# Calculate the percentage of missing values for each column
missing_percentage = data.isna().mean() * 100

# %%
# Create a DataFrame to display the results
missing_df = pd.DataFrame({
    'Column Name': missing_percentage.index,
    'Missing Percentage': missing_percentage.values
})

# Print the DataFrame
print(missing_df)
# Out:
#           Column Name  Missing Percentage
# 0                Name            0.000000
# 1            COMPLETE            1.333333
# 2       Stroke volume            0.000000
# 3                 PRN            6.666667
# 4                 age            2.000000
# ..                ...                 ...
# 67          Lt A1 ACA            0.000000
# 68  clot burden score            0.000000
# 69      Lt ICA origin            2.000000
# 70      Rt ICA origin            2.000000
# 71                CCA           82.666667
#
# [72 rows x 2 columns]

# %%
# Optionally, save the results to a new Excel file
missing_df.to_excel('missing_values_percentage.xlsx', index=False)
